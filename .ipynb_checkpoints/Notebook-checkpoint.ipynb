# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %%
bs = 8  
sz = 224 
PATH = './Images/'

# %%
classes = []
for d in os.listdir(PATH):
    if os.path.isdir(os.path.join(PATH, d)) and not d.startswith('.'):
        classes.append(d) 
print ("There are ", len(classes), "classes:\n", classes)
# Out:
# There are  2 classes:
#  ['Gate', 'Space']

# %%
for c in classes:
    print ("Class:", c)
    verify_images(os.path.join(PATH, c), delete=True);
# Out:
# Class: Gate
# Class: Space

# %%
data  = ImageDataBunch.from_folder(PATH, ds_tfms=get_transforms(), size=sz, bs=bs, valid_pct=0.2).normalize(imagenet_stats)

# %%
print ("There are", len(data.train_ds), "training images and", len(data.valid_ds), "validation images." )
# Out:
# There are 88 training images and 21 validation images.

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
learn = cnn_learner(data, models.resnet34, metrics=accuracy)

# %%
learn.save('final_model_drone.h5')

# %%
learn.lr_find();
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='7' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       70.00% [7/10 05:39<02:25]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.210780</td>
#       <td>#na#</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.361160</td>
#       <td>#na#</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.165531</td>
#       <td>#na#</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.043396</td>
#       <td>#na#</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.871565</td>
#       <td>#na#</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.716450</td>
#       <td>#na#</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.654575</td>
#       <td>#na#</td>
#       <td>00:46</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='7' class='' max='11', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       63.64% [7/11 00:35<00:20 0.6979]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(4, max_lr=slice(1e-3,1e-2))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.422299</td>
#       <td>0.213268</td>
#       <td>0.952381</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.290308</td>
#       <td>0.001598</td>
#       <td>1.000000</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.362260</td>
#       <td>0.000019</td>
#       <td>1.000000</td>
#       <td>01:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.249836</td>
#       <td>0.000007</td>
#       <td>1.000000</td>
#       <td>00:57</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.plot_top_losses(4, figsize=(15,11), heatmap=False)

# %%
path = './GateAndspace/' #The path of test image Gate or Space
img = open_image(get_image_files(path)[0])
pred_class,pred_idx,outputs = learn.predict(img)
img.show()
print ("It is a", pred_class)
# Out:
# It is a Space

# %%
learn.save('final_model_h5.h5')
